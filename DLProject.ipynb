# %% [markdown]
# <a href="https://colab.research.google.com/github/Ritukuklani/Deep-Learning/blob/main/DLProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pwd
# Out:
# '/content'

# %%
cd drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
# !git clone "https://github.com/sephirothx/snake-dqn.git"
# Out:
# fatal: destination path 'snake-dqn' already exists and is not an empty directory.

# %%
ls
# Out:
# '10th april'/
# '12th may'/
# '21st jan'/
# '22nd feb'/
# '25th march'/
# '26th april'/
# '28th may'/
#  2.txt.gdoc
# '5th jan'/
# '6th feb'/
# '9th march'/
#  ADC-MCA.txt
#  allseasonalityparameters.rtf
#  alppaydin_machinelearning_2010.gdoc
#  alppaydin_machinelearning_2010.pdf
#  ans.txt
# 'assign 52.txt.gdoc'
# 'BE SEm 1 Report Format for 2018-19(5).docx'
# 'BE SEm 1 Report Format for 2018-19(5).gdoc'
#  boomerang_D244.mp4
# 'Central Park'/
# 'Colab Notebooks'/
# 'Coney island'/
# 'Contact Information (1).gform'
# 'Contact Information.gform'
# 'Copy of bday song.aiff'
#  data/
#  deep-q-snake/
#  DSC_0001.NEF
#  DSC_0003.JPG
#  DSC_0004.JPG
#  DSC_0005.JPG
#  DSC_0006.JPG
#  DSC_0030.NEF
#  DSC_0048.NEF
#  _DSC0050-1.JPG
#  _DSC0050-2.JPG
#  DSC_0070.JPG
#  _DSC0078-2.JPG
#  _DSC0079-3.JPG
#  _DSC0080.JPG
#  _DSC0082-2.JPG
#  DSC_0084.JPG
#  _DSC0110.JPG
#  _DSC0112.JPG
#  _DSC0115.JPG
#  _DSC0151.JPG
#  _DSC0152.JPG
#  DSC_0411.JPG
#  DSC_0412.JPG
#  DSC_0414.JPG
# ...

# %%
cd snake-dqn/
# Out:
# /content/drive/MyDrive/snake-dqn

# %%
# !ls
# Out:
# models	requirements.txt  src

# %%
cd models
# Out:
# /content/drive/MyDrive/snake-dqn/models

# %%
ls
# Out:
# 10x10v1___19.00max___-4.44avg__-28.00min.model
# 10x10v1___44.00max____2.04avg__-26.00min.model

# %%
cd src
# Out:
# /content/drive/MyDrive/snake-dqn/src

# %%
ls
# Out:
# DQNAgent.py  main.py  models/  ModifiedTensorBoard.py  __pycache__/  snake.py

# %%
# !python "main.py"
# Out:
# Streaming output truncated to the last 5000 lines.
#  62% 12443/20000 [3:37:35<2:37:08,  1.25s/episode]  Episode: 12444   Score: 6
#  62% 12444/20000 [3:37:36<2:34:09,  1.22s/episode]  Episode: 12445   Score: 4
#  62% 12445/20000 [3:37:36<2:01:36,  1.04episode/s]  Episode: 12446   Score: 13
#  62% 12446/20000 [3:37:39<2:50:11,  1.35s/episode]  Episode: 12447   Score: 3
#  62% 12447/20000 [3:37:39<2:34:43,  1.23s/episode]  Episode: 12448   Score: 2
#  62% 12448/20000 [3:37:40<2:00:55,  1.04episode/s]  Episode: 12449   Score: 5
#  62% 12449/20000 [3:37:42<2:45:50,  1.32s/episode]  Episode: 12450   Score: 3
#  62% 12450/20000 [3:37:44<3:13:48,  1.54s/episode]  Episode: 12451   Score: 3
#  62% 12451/20000 [3:37:45<2:54:08,  1.38s/episode]  Episode: 12452   Score: 6
#  62% 12452/20000 [3:37:46<2:37:26,  1.25s/episode]  Episode: 12453   Score: 0
#  62% 12453/20000 [3:37:46<2:09:33,  1.03s/episode]  Episode: 12454   Score: 1
# ...
